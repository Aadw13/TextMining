# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import urllib.request

# %%
response=urllib.request.urlopen("https://www.lenovo.com/in/en/")
html=response.read()
html
# Out:
# b'<!doctype html>\n<html lang="EN" class="no-js core-v1">\n\n<head>\n\t<title>Lenovo Official India Site | Laptops, Tablets, Desktops, Data Center | Lenovo India</title>\n    <meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\t<meta name=\'viewport\' content=\'width=device-width,initial-scale=1.0\'>\n\t<meta name=\'description\' content=\'Visit Lenovo India official site and buy online the best laptops, notebooks, tablets, data centers & desktops for your home and business.\'>\n\t<meta name=\'taxonomytype\' content=\'homepage\'>\n\t<meta name=\'title\' content=\'Lenovo Official India Site | Laptops, Tablets, Desktops, Data Center\'>\n\t<meta name=\'PageTitle\' content=\'IN-NEW-HP-FTV\'>\n\t<meta name=\'pageName\' content=\'IN-NEW-HP-FTV\'>\n\t<meta name=\'language\' content=\'en\'>\n\t<meta name=\'lc\' content=\'en\'>\n\t<meta name=\'lenovo.language\' content=\'en\'>\n\t<meta name=\'dc.language\' content=\'en\'>\n\t<meta name=\'country\' content=\'IN\'>\n\t<meta name=\'cc\' content=\'IN\'>\n\t<meta name=\'lenovo.country\' content=\'IN\'>\n\t<meta name=\'regioncode\' content=\'SASIA\'>\n\t<meta name=\'currencycode\' content=\'INR\'>\n\t<meta name=\'currency\' content=\'INR\'>\n\t<meta name=\'originStore\' content=\'inweb\'>\n\t<meta name=\'bu\' content=\'PUBLIC_CONSUMER\'>\n\t<meta name=\'area\' content=\'PUBLIC_CONSUMER\'>\n\t<meta name=\'storeinfo.storetype\' content=\'PUBLIC_CONSUMER\'>\n\t<meta name=\'storeType\' content=\'PUBLIC_CONSUMER\'>\n\t<meta name=\'storeinfo.storeid\' content=\'INWEB\'>\n\t<meta name=\'storeID\' content=\'inweb\'>\n\t<meta name=\'BPID\' content=\'1214287630\'>\n\t<meta name=\'storeinfo.salestype\' content=\'DIRECT\'>\n\t<meta name=\'siteRoot\' content=\'/in/en\'>\n\t<meta name=\'internalsearchcanonical\' content=\'/in/en/\'>\n\t<link rel="canonical" href="https://www.lenovo.com/in/en/">\n\t<meta name=\'robots\' content=\'INDEX,FOLLOW\'>\n\t<meta name=\'platform\' content=\'MFE\'>\n\n<!--css StandAlone Start--><link type="text/css" rel="stylesheet" media="all" href="//static.lenovo.com/fea/css/core.css"/>\n<link type="text/css" rel="stylesheet" media="all" href="//static.lenovo.com/fea/css/globalMsg.css"/>\n<!--css StandAlone End-->\n<!--css Component Start--><link type="text/css" rel="stylesheet" media="all" href="//static.lenovo.com/fea/css/organisms/variants/o-bannerFlip.css"/>\n<link type="text/css" rel="stylesheet" media="all" href="//static.lenovo.com/fea/css/molecules/m-youtube.css"/>\n<!--css Component End-->\n\n        <link type="text/css" rel="stylesheet" media="all" href="//static.lenovo.com/fea/css/shame/header/coreMasthead.css"/>\n\n\n        <link type="text/css" rel="stylesheet" media="all" href="//static.lenovo.com/fea/css/coreFooter.css"/>\n\n<!--js Head Start--><script type="text/javascript" src="//static.lenovo.com/fea/js/vendor/modernizr.js"></script>\n<script type="text/javascript" src="//static.lenovo.com/fea/js/temp/jquery-3.3.1-w-migrate.js"></script>\n<script type="text/javascript" src="//static.lenovo.com/fea/js/vendor/analyticsmediator.js?v=20180309081517"></script>\n<script type="text/javascript" src="//static.lenovo.com/fea/js/adobeAnalytics/AdobeAnalyticsEvent.js"></script>\n<script type="text/javascript">var modalLabels = window.modalLabels ? modalLabels : {};\n      modalLabels.localization = {"close" : "Close", "loading" : "Loading..."};</script>\n<script type="text/javascript" src="//static.lenovo.com/fea/js/vendor/handlebars.runtime.min.js"></script>\n<script type="text/javascript" src="//static.lenovo.com/fea/js/common/globalErrorMsg.js"></script>\n<script type="text/javascript" src="//static.lenovo.com/fea/js/common/lenovoapp.js"></script>\n<script type="text/javascript" src="//static.lenovo.com/fea/js/vendor/customerCookieData.js"></script>\n<!--js Head End-->\n\n<!-- page.yottaFlag: false -->\n<script src="https://cdn.yottaa.com/rapid.min.js"></script>\n<scrip ...

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(html,"html5lib")
text=soup.get_text(strip=True)
text
# Out:
# 'Lenovo Official India Site | Laptops, Tablets, Desktops, Data Center | Lenovo Indiavar modalLabels = window.modalLabels ? modalLabels : {};\n      modalLabels.localization = {"close" : "Close", "loading" : "Loading..."};Yo.configure(\'https://qoe-1.yottaa.net/api/v1/configure.rapid.js?key=UcFvHNNMgYjHuw\');\n    if(!window.lmd)  var lmd={};\n    lmd.yottaa = window.Yo ? Yo.rum.get().optState : \'yo-not-present\';var utag_data={country_code: "IN",\n        \tlanguage_code:"EN",order_currency_code: "INR",\n       \t\tsite_id: "INWEB",\n            customer_email: displayUid, customer_name: custName};LenovoExploreClosePC & TABLETSPC & TABLETSSaleFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Great DealsBusiness DealsStudent LaptopsTablets & Accessories dealsGaming DealsClearance SaleOther DealsLaptops Under 50KAMD DealsWorkstation DealsAll-in-One DealsNew ArrivalsLENOVOPRO FOR BUSINESSJoin Now to Unlock free digital courses, Gsuite licenses and easy financing options with the support of dedicated small business specialists.Amazing DealsSave big on our top brands for work, school, gaming and much more while supplies last.LaptopsFree shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore LaptopsUltra-SlimBusiness LaptopsStudent Laptop DealsConvertiblesGaming LaptopsView All LaptopsBy BrandThinkPadThinkBookIdeaPadYogaLegionLenovoBest Selling LaptopsLegion 5Ideapad Flex 5Yoga Slim 7Thinkpad E14ThinkBook 14Legion Y540Unshackle performance. Unfetter sensibilitiesThinkBook Plus is powered by the latest 10th Gen Intel® Core™ processors with up to 6 cores that delivers breakthrough performanceDesktopsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore DesktopsGaming DesktopsWorkstationsBusiness DesktopsTiny DesktopsView All DesktopsBy BrandThinkCentreIdeaCentreLegionThinkStationLenovoBest Selling DesktopsIdeaCentre AIO 3IdeaCentre AIO 5AIO 340 55.88cms (22)AIO 340 60.96cms (24)Legion T530 TowerIdeaCentre 310sWEEKLY DESKTOP DEALSClick here for the best deals on desktops for work, home, gaming & more.WorkstationsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore WorkstationsMobile WorkstationsDesktop WorkstationsView all WorkstationsWorkstation DealsBy BrandThinkPadThinkstationWorkstation DealsCheckout the best deals on WorkstationsNEW IN! ThinkPad P14s & P15sNow with 10th Gen Processor.TabletsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore TabletsWith Android2-in-1 TabletsNewly LaunchedSmart HomeView all TabletsBest Selling TabletsFor KidsFor PerformanceFor a GiftBest BargainIT IS TIME TO UN-LAPTOP, AND GOThe perfect balance between tablet portability and Chromebook utilityTablet DealsFind the perfect tablet or smart device for you and the whole family. Enjoy weekly discounts today!AccessoriesFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733ProductsDocksChargers & BatteriesMice & KeyboardCables & AdaptersCases & BagsView All AccessoriesFeaturedGaming AccessoriesStudent AccessoriesAccessories FinderFind the right accessory for your machineMonitorsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore MonitorsMonitors for WorkMonitors for HomeMonitors for GamingView All MonitorsMonitor SaleShop Weekly deals & complete your work from home, gaming or school set up today!THINKVISION M14tExperience work on-the-go like no otherGamingFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore GamingLaptopsDesktopsMonitorsAccessoriesCustomized Gaming LaptopsBest Selling ProductsLegion 5iIdeaPad Gaming 3iIdeaPad L340Legion Y540Legion 7iLegion Y7000Types of GamingAvid GamingLight GamingCustomized Gaming LaptopsYour Gaming PC. Your Configurations. Your DealsBusiness SolutionsBusiness SolutionsDevice as a Service (DAAS)Premier SupportFactory S ...

# %%
from nltk.tokenize import sent_tokenize
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Lenovo Official India Site | Laptops, Tablets, Desktops, Data Center | Lenovo Indiavar modalLabels = window.modalLabels ?', 'modalLabels : {};\n      modalLabels.localization = {"close" : "Close", "loading" : "Loading..."};Yo.configure(\'https://qoe-1.yottaa.net/api/v1/configure.rapid.js?key=UcFvHNNMgYjHuw\');\n    if(!window.lmd)  var lmd={};\n    lmd.yottaa = window.Yo ?', 'Yo.rum.get().optState : \'yo-not-present\';var utag_data={country_code: "IN",\n        \tlanguage_code:"EN",order_currency_code: "INR",\n       \t\tsite_id: "INWEB",\n            customer_email: displayUid, customer_name: custName};LenovoExploreClosePC & TABLETSPC & TABLETSSaleFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Great DealsBusiness DealsStudent LaptopsTablets & Accessories dealsGaming DealsClearance SaleOther DealsLaptops Under 50KAMD DealsWorkstation DealsAll-in-One DealsNew ArrivalsLENOVOPRO FOR BUSINESSJoin Now to Unlock free digital courses, Gsuite licenses and easy financing options with the support of dedicated small business specialists.Amazing DealsSave big on our top brands for work, school, gaming and much more while supplies last.LaptopsFree shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore LaptopsUltra-SlimBusiness LaptopsStudent Laptop DealsConvertiblesGaming LaptopsView All LaptopsBy BrandThinkPadThinkBookIdeaPadYogaLegionLenovoBest Selling LaptopsLegion 5Ideapad Flex 5Yoga Slim 7Thinkpad E14ThinkBook 14Legion Y540Unshackle performance.', 'Unfetter sensibilitiesThinkBook Plus is powered by the latest 10th Gen Intel® Core™ processors with up to 6 cores that delivers breakthrough performanceDesktopsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore DesktopsGaming DesktopsWorkstationsBusiness DesktopsTiny DesktopsView All DesktopsBy BrandThinkCentreIdeaCentreLegionThinkStationLenovoBest Selling DesktopsIdeaCentre AIO 3IdeaCentre AIO 5AIO 340 55.88cms (22)AIO 340 60.96cms (24)Legion T530 TowerIdeaCentre 310sWEEKLY DESKTOP DEALSClick here for the best deals on desktops for work, home, gaming & more.WorkstationsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore WorkstationsMobile WorkstationsDesktop WorkstationsView all WorkstationsWorkstation DealsBy BrandThinkPadThinkstationWorkstation DealsCheckout the best deals on WorkstationsNEW IN!', 'ThinkPad P14s & P15sNow with 10th Gen Processor.TabletsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore TabletsWith Android2-in-1 TabletsNewly LaunchedSmart HomeView all TabletsBest Selling TabletsFor KidsFor PerformanceFor a GiftBest BargainIT IS TIME TO UN-LAPTOP, AND GOThe perfect balance between tablet portability and Chromebook utilityTablet DealsFind the perfect tablet or smart device for you and the whole family.', 'Enjoy weekly discounts today!AccessoriesFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733ProductsDocksChargers & BatteriesMice & KeyboardCables & AdaptersCases & BagsView All AccessoriesFeaturedGaming AccessoriesStudent AccessoriesAccessories FinderFind the right accessory for your machineMonitorsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore MonitorsMonitors for WorkMonitors for HomeMonitors for GamingView All MonitorsMonitor SaleShop Weekly deals & complete your work from home, gaming or school set up today!THINKVISION M14tExperience work on-the-go like no otherGamingFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore GamingLaptopsDesktopsMonitorsAccessoriesCustomized Gaming LaptopsBest Selling ProductsLegion 5iIdeaPad Gaming 3iIdeaPad L340Legion Y540Legion 7iLegion Y7000Types of GamingAvid GamingLight GamingCustomized Gaming LaptopsYour Gaming PC.', 'Your Configurations.', 'Your DealsBusiness SolutionsBusiness SolutionsDevice as a Service (DAAS)Pr ...

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Lenovo', 'Official', 'India', 'Site', '|', 'Laptops', ',', 'Tablets', ',', 'Desktops', ',', 'Data', 'Center', '|', 'Lenovo', 'Indiavar', 'modalLabels', '=', 'window.modalLabels', '?', 'modalLabels', ':', '{', '}', ';', 'modalLabels.localization', '=', '{', '``', 'close', "''", ':', '``', 'Close', "''", ',', '``', 'loading', "''", ':', '``', 'Loading', '...', "''", '}', ';', 'Yo.configure', '(', "'https", ':', '//qoe-1.yottaa.net/api/v1/configure.rapid.js', '?', 'key=UcFvHNNMgYjHuw', "'", ')', ';', 'if', '(', '!', 'window.lmd', ')', 'var', 'lmd=', '{', '}', ';', 'lmd.yottaa', '=', 'window.Yo', '?', 'Yo.rum.get', '(', ')', '.optState', ':', "'yo-not-present", "'", ';', 'var', 'utag_data=', '{', 'country_code', ':', '``', 'IN', "''", ',', 'language_code', ':', "''", 'EN', "''", ',', 'order_currency_code', ':', '``', 'INR', "''", ',', 'site_id', ':', '``', 'INWEB', "''", ',', 'customer_email', ':', 'displayUid', ',', 'customer_name', ':', 'custName', '}', ';', 'LenovoExploreClosePC', '&', 'TABLETSPC', '&', 'TABLETSSaleFree', 'Shipping6', 'Months', 'No-cost', 'EMIBuild', 'your', 'own', 'laptopTo', 'buy', ',', 'call', 'us', 'on', '1800', '4199', '733Great', 'DealsBusiness', 'DealsStudent', 'LaptopsTablets', '&', 'Accessories', 'dealsGaming', 'DealsClearance', 'SaleOther', 'DealsLaptops', 'Under', '50KAMD', 'DealsWorkstation', 'DealsAll-in-One', 'DealsNew', 'ArrivalsLENOVOPRO', 'FOR', 'BUSINESSJoin', 'Now', 'to', 'Unlock', 'free', 'digital', 'courses', ',', 'Gsuite', 'licenses', 'and', 'easy', 'financing', 'options', 'with', 'the', 'support', 'of', 'dedicated', 'small', 'business', 'specialists.Amazing', 'DealsSave', 'big', 'on', 'our', 'top', 'brands', 'for', 'work', ',', 'school', ',', 'gaming', 'and', 'much', 'more', 'while', 'supplies', 'last.LaptopsFree', 'shipping6', 'Months', 'No-cost', 'EMIBuild', 'your', 'own', 'laptopTo', 'buy', ',', 'call', 'us', 'on', '1800', '4199', '733Explore', 'LaptopsUltra-SlimBusiness', 'LaptopsStudent', 'Laptop', 'DealsConvertiblesGaming', 'LaptopsView', 'All', 'LaptopsBy', 'BrandThinkPadThinkBookIdeaPadYogaLegionLenovoBest', 'Selling', 'LaptopsLegion', '5Ideapad', 'Flex', '5Yoga', 'Slim', '7Thinkpad', 'E14ThinkBook', '14Legion', 'Y540Unshackle', 'performance', '.', 'Unfetter', 'sensibilitiesThinkBook', 'Plus', 'is', 'powered', 'by', 'the', 'latest', '10th', 'Gen', 'Intel®', 'Core™', 'processors', 'with', 'up', 'to', '6', 'cores', 'that', 'delivers', 'breakthrough', 'performanceDesktopsFree', 'Shipping6', 'Months', 'No-cost', 'EMIBuild', 'your', 'own', 'laptopTo', 'buy', ',', 'call', 'us', 'on', '1800', '4199', '733Explore', 'DesktopsGaming', 'DesktopsWorkstationsBusiness', 'DesktopsTiny', 'DesktopsView', 'All', 'DesktopsBy', 'BrandThinkCentreIdeaCentreLegionThinkStationLenovoBest', 'Selling', 'DesktopsIdeaCentre', 'AIO', '3IdeaCentre', 'AIO', '5AIO', '340', '55.88cms', '(', '22', ')', 'AIO', '340', '60.96cms', '(', '24', ')', 'Legion', 'T530', 'TowerIdeaCentre', '310sWEEKLY', 'DESKTOP', 'DEALSClick', 'here', 'for', 'the', 'best', 'deals', 'on', 'desktops', 'for', 'work', ',', 'home', ',', 'gaming', '&', 'more.WorkstationsFree', 'Shipping6', 'Months', 'No-cost', 'EMIBuild', 'your', 'own', 'laptopTo', 'buy', ',', 'call', 'us', 'on', '1800', '4199', '733Explore', 'WorkstationsMobile', 'WorkstationsDesktop', 'WorkstationsView', 'all', 'WorkstationsWorkstation', 'DealsBy', 'BrandThinkPadThinkstationWorkstation', 'DealsCheckout', 'the', 'best', 'deals', 'on', 'WorkstationsNEW', 'IN', '!', 'ThinkPad', 'P14s', '&', 'P15sNow', 'with', '10th', 'Gen', 'Processor.TabletsFree', 'Shipping6', 'Months', 'No-cost', 'EMIBuild', 'your', 'own', 'laptopTo', 'buy', ',', 'call', 'us', 'on', '1800', '4199', '733Explore', 'TabletsWith', 'Android2-in-1', 'TabletsNewly', 'LaunchedSmart', 'HomeView', 'all', 'TabletsBest', 'Selling', 'TabletsFor', 'KidsFor', 'PerformanceFor', 'a', 'GiftBest', 'BargainIT', 'IS', 'TIME', 'TO', 'UN-LAPTOP', ',', 'AND', 'GOThe', 'perfect', 'balance', 'between', 'tablet', 'portability', 'and', ' ...

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 919 samples and 3779 outcomes>

# %%
fdist.most_common(2)
# Out:
# [('(', 312), (')', 312)]

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'down', "didn't", 'myself', 'will', 'or', 'on', "aren't", 'in', 'whom', 'this', 'my', "isn't", 'those', 'mightn', "won't", 'were', 'each', 'all', "shan't", 'out', 'now', 'wasn', "mightn't", 'an', 'who', 'too', 'needn', 'm', 'both', 'yourselves', 'we', 'ourselves', 'over', "she's", 'any', "haven't", 'a', 'our', "that'll", 'is', 'should', 'it', 'shouldn', 'being', 'did', 'ain', 'does', 'not', "you'll", 're', 'that', 'when', 'while', 'of', 'o', "hadn't", 'd', "wouldn't", 'herself', 'most', 'than', "don't", 't', 'again', 'having', 'at', 'above', 'below', 'where', 'here', 'before', 'you', "weren't", 'me', 'such', 'hers', 'very', 'under', "should've", 'during', 'don', 'isn', 'their', 'her', 'wouldn', 'him', 'no', 'once', 'had', 'he', 'am', 'the', 'up', 'itself', 'until', 'theirs', 'same', 'be', "you've", 'about', 'aren', 'through', 'ma', 'she', "couldn't", 'have', 'few', 'didn', "mustn't", 'your', 'doesn', 'then', 'nor', 'there', 'as', 'other', 'can', 'own', 'y', 'weren', 'off', 'won', 'what', "you're", "it's", 'couldn', 'been', 'yourself', 'shan', 'after', 'they', 'some', 'from', 'ours', 'because', "needn't", 'further', 'll', 'with', 'into', 'his', 'its', 'if', 'for', 'why', 'i', 's', "you'd", 'between', "shouldn't", 'these', 'yours', 'are', 'against', 'hadn', 'haven', 'but', 'them', 'himself', 'by', 'more', 'has', 'do', 'doing', 've', "doesn't", "hasn't", 'to', 'mustn', 'only', 'and', 'just', 'themselves', 'hasn', 'was', 'so', 'which', 'how', "wasn't"}

# %%
filtered_sent=[]
for w in tokenized_text:
    if w not in stop_words:
        filtered_sent.append(w)
print("Tokenized Sentence:",tokenized_sent)
print("Filterd Sentence:",filtered_sent)
# Out:
# Tokenized Sentence: []
# Filterd Sentence: ['Lenovo Official India Site | Laptops, Tablets, Desktops, Data Center | Lenovo Indiavar modalLabels = window.modalLabels ?', 'modalLabels : {};\n      modalLabels.localization = {"close" : "Close", "loading" : "Loading..."};Yo.configure(\'https://qoe-1.yottaa.net/api/v1/configure.rapid.js?key=UcFvHNNMgYjHuw\');\n    if(!window.lmd)  var lmd={};\n    lmd.yottaa = window.Yo ?', 'Yo.rum.get().optState : \'yo-not-present\';var utag_data={country_code: "IN",\n        \tlanguage_code:"EN",order_currency_code: "INR",\n       \t\tsite_id: "INWEB",\n            customer_email: displayUid, customer_name: custName};LenovoExploreClosePC & TABLETSPC & TABLETSSaleFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Great DealsBusiness DealsStudent LaptopsTablets & Accessories dealsGaming DealsClearance SaleOther DealsLaptops Under 50KAMD DealsWorkstation DealsAll-in-One DealsNew ArrivalsLENOVOPRO FOR BUSINESSJoin Now to Unlock free digital courses, Gsuite licenses and easy financing options with the support of dedicated small business specialists.Amazing DealsSave big on our top brands for work, school, gaming and much more while supplies last.LaptopsFree shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore LaptopsUltra-SlimBusiness LaptopsStudent Laptop DealsConvertiblesGaming LaptopsView All LaptopsBy BrandThinkPadThinkBookIdeaPadYogaLegionLenovoBest Selling LaptopsLegion 5Ideapad Flex 5Yoga Slim 7Thinkpad E14ThinkBook 14Legion Y540Unshackle performance.', 'Unfetter sensibilitiesThinkBook Plus is powered by the latest 10th Gen Intel® Core™ processors with up to 6 cores that delivers breakthrough performanceDesktopsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore DesktopsGaming DesktopsWorkstationsBusiness DesktopsTiny DesktopsView All DesktopsBy BrandThinkCentreIdeaCentreLegionThinkStationLenovoBest Selling DesktopsIdeaCentre AIO 3IdeaCentre AIO 5AIO 340 55.88cms (22)AIO 340 60.96cms (24)Legion T530 TowerIdeaCentre 310sWEEKLY DESKTOP DEALSClick here for the best deals on desktops for work, home, gaming & more.WorkstationsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore WorkstationsMobile WorkstationsDesktop WorkstationsView all WorkstationsWorkstation DealsBy BrandThinkPadThinkstationWorkstation DealsCheckout the best deals on WorkstationsNEW IN!', 'ThinkPad P14s & P15sNow with 10th Gen Processor.TabletsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore TabletsWith Android2-in-1 TabletsNewly LaunchedSmart HomeView all TabletsBest Selling TabletsFor KidsFor PerformanceFor a GiftBest BargainIT IS TIME TO UN-LAPTOP, AND GOThe perfect balance between tablet portability and Chromebook utilityTablet DealsFind the perfect tablet or smart device for you and the whole family.', 'Enjoy weekly discounts today!AccessoriesFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733ProductsDocksChargers & BatteriesMice & KeyboardCables & AdaptersCases & BagsView All AccessoriesFeaturedGaming AccessoriesStudent AccessoriesAccessories FinderFind the right accessory for your machineMonitorsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore MonitorsMonitors for WorkMonitors for HomeMonitors for GamingView All MonitorsMonitor SaleShop Weekly deals & complete your work from home, gaming or school set up today!THINKVISION M14tExperience work on-the-go like no otherGamingFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore GamingLaptopsDesktopsMonitorsAccessoriesCustomized Gaming LaptopsBest Selling ProductsLegion 5iIdeaPad Gaming 3iIdeaPad L340Legion Y540Legion 7iLegion Y7000Types of GamingAvid GamingLight GamingCustomized Gaming LaptopsYour Gaming PC.', 'Your Configurations.', 'Your DealsBusiness SolutionsBusiness SolutionsDevice as  ...

# %%
tokens=[t for t in text.split()]
tokens
# Out:
# ['Lenovo',
#  'Official',
#  'India',
#  'Site',
#  '|',
#  'Laptops,',
#  'Tablets,',
#  'Desktops,',
#  'Data',
#  'Center',
#  '|',
#  'Lenovo',
#  'Indiavar',
#  'modalLabels',
#  '=',
#  'window.modalLabels',
#  '?',
#  'modalLabels',
#  ':',
#  '{};',
#  'modalLabels.localization',
#  '=',
#  '{"close"',
#  ':',
#  '"Close",',
#  '"loading"',
#  ':',
#  '"Loading..."};Yo.configure(\'https://qoe-1.yottaa.net/api/v1/configure.rapid.js?key=UcFvHNNMgYjHuw\');',
#  'if(!window.lmd)',
#  'var',
#  'lmd={};',
#  'lmd.yottaa',
#  '=',
#  'window.Yo',
#  '?',
#  'Yo.rum.get().optState',
#  ':',
#  "'yo-not-present';var",
#  'utag_data={country_code:',
#  '"IN",',
#  'language_code:"EN",order_currency_code:',
#  '"INR",',
#  'site_id:',
#  '"INWEB",',
#  'customer_email:',
#  'displayUid,',
#  'customer_name:',
#  'custName};LenovoExploreClosePC',
#  '&',
#  'TABLETSPC',
#  '&',
#  'TABLETSSaleFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Great',
#  'DealsBusiness',
#  'DealsStudent',
#  'LaptopsTablets',
#  '&',
#  'Accessories',
#  'dealsGaming',
#  'DealsClearance',
#  'SaleOther',
#  'DealsLaptops',
#  'Under',
#  '50KAMD',
#  'DealsWorkstation',
#  'DealsAll-in-One',
#  'DealsNew',
#  'ArrivalsLENOVOPRO',
#  'FOR',
#  'BUSINESSJoin',
#  'Now',
#  'to',
#  'Unlock',
#  'free',
#  'digital',
#  'courses,',
#  'Gsuite',
#  'licenses',
#  'and',
#  'easy',
#  'financing',
#  'options',
#  'with',
#  'the',
#  'support',
#  'of',
#  'dedicated',
#  'small',
#  'business',
#  'specialists.Amazing',
#  'DealsSave',
#  'big',
#  'on',
#  'our',
#  'top',
#  'brands',
#  'for',
#  'work,',
#  'school,',
#  'gaming',
#  'and',
#  'much',
#  'more',
#  'while',
#  'supplies',
#  'last.LaptopsFree',
#  'shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Explore',
#  'LaptopsUltra-SlimBusiness',
#  'LaptopsStudent',
#  'Laptop',
#  'DealsConvertiblesGaming',
#  'LaptopsView',
#  'All',
#  'LaptopsBy',
#  'BrandThinkPadThinkBookIdeaPadYogaLegionLenovoBest',
#  'Selling',
#  'LaptopsLegion',
#  '5Ideapad',
#  'Flex',
#  '5Yoga',
#  'Slim',
#  '7Thinkpad',
#  'E14ThinkBook',
#  '14Legion',
#  'Y540Unshackle',
#  'performance.',
#  'Unfetter',
#  'sensibilitiesThinkBook',
#  'Plus',
#  'is',
#  'powered',
#  'by',
#  'the',
#  'latest',
#  '10th',
#  'Gen',
#  'Intel®',
#  'Core™',
#  'processors',
#  'with',
#  'up',
#  'to',
#  '6',
#  'cores',
#  'that',
#  'delivers',
#  'breakthrough',
#  'performanceDesktopsFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Explore',
#  'DesktopsGaming',
#  'DesktopsWorkstationsBusiness',
#  'DesktopsTiny',
#  'DesktopsView',
#  'All',
#  'DesktopsBy',
#  'BrandThinkCentreIdeaCentreLegionThinkStationLenovoBest',
#  'Selling',
#  'DesktopsIdeaCentre',
#  'AIO',
#  '3IdeaCentre',
#  'AIO',
#  '5AIO',
#  '340',
#  '55.88cms',
#  '(22)AIO',
#  '340',
#  '60.96cms',
#  '(24)Legion',
#  'T530',
#  'TowerIdeaCentre',
#  '310sWEEKLY',
#  'DESKTOP',
#  'DEALSClick',
#  'here',
#  'for',
#  'the',
#  'best',
#  'deals',
#  'on',
#  'desktops',
#  'for',
#  'work,',
#  'home,',
#  'gaming',
#  '&',
#  'more.WorkstationsFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Explore',
#  'WorkstationsMobile',
#  'WorkstationsDesktop',
#  'WorkstationsView',
#  'all',
#  'WorkstationsWorkstation',
#  'DealsBy',
#  'BrandThinkPadThinkstationWorkstation',
#  'DealsCheckout',
#  'the',
#  'best',
#  'deals',
#  'on',
#  'WorkstationsNEW',
#  'IN!',
#  'ThinkPad',
#  'P14s',
#  '&',
#  'P15sNow',
#  'with',
#  '10th',
#  'Gen',
#  'Processor.TabletsFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Explore',
#  'TabletsWith',
#  'Android2-in-1',
#  'TabletsNewly',
#  'LaunchedSmart',
#  'HomeView',
#  'all',
#  'TabletsBest',
#  'Selling',
#  'TabletsFor',
#  'KidsFor',
#  'PerformanceFor',
#  'a',
#  'GiftBest',
#  'BargainIT',
#  'IS',
#  'TIME',
#  'TO',
#  'UN-LAPTOP,',
#  'AND',
#  'GOThe',
#  'perfect',
#  'balance',
#  'between',
#  'tablet',
#  'portability',
#  'and',
#  'Chromebook',
#  'utilityTablet',
#  'DealsFind',
#  'the',
#  'perfect',
#  'tablet',
#  'or',
#  'smart',
#  'device',
#  'for',
#  'you',
#  'and',
#  'the',
#  'whole',
#  'family.',
#  'Enjoy',
#  'weekly',
#  'discounts',
#  'today!AccessoriesFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733ProductsDocksChargers',
#  '&',
#  'BatteriesMice',
#  '&',
#  'KeyboardCables',
#  '&',
#  'AdaptersCases',
#  '&',
#  'BagsView',
#  'All',
#  'AccessoriesFeaturedGaming',
#  'AccessoriesStudent',
#  'AccessoriesAccessories',
#  'FinderFind',
#  'the',
#  'right',
#  'accessory',
#  'for',
#  'your',
#  'machineMonitorsFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Explore',
#  'MonitorsMonitors',
#  'for',
#  'WorkMonitors',
#  'for',
#  'HomeMonitors',
#  'for',
#  'GamingView',
#  'All',
#  'MonitorsMonitor',
#  'SaleShop',
#  'Weekly',
#  'deals',
#  '&',
#  'complete',
#  'your',
#  'work',
#  'from',
#  'home,',
#  'gaming',
#  'or',
#  'school',
#  'set',
#  'up',
#  'today!THINKVISION',
#  'M14tExperience',
#  'work',
#  'on-the-go',
#  'like',
#  'no',
#  'otherGamingFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Explore',
#  'GamingLaptopsDesktopsMonitorsAccessoriesCustomized',
#  'Gaming',
#  'LaptopsBest',
#  'Selling',
#  'ProductsLegion',
#  '5iIdeaPad',
#  'Gaming',
#  '3iIdeaPad',
#  'L340Legion',
#  'Y540Legion',
#  '7iLegion',
#  'Y7000Types',
#  'of',
#  'GamingAvid',
#  'GamingLight',
#  'GamingCustomized',
#  'Gaming',
#  'LaptopsYour',
#  'Gaming',
#  'PC.',
#  'Your',
#  'Configurations.',
#  'Your',
#  'DealsBusiness',
#  'SolutionsBusiness',
#  'SolutionsDevice',
#  'as',
#  'a',
#  'Service',
#  '(DAAS)Premier',
#  'SupportFactory',
#  'ServicesReplacement',
#  'Parts3',
#  'year',
#  'warranty',
#  'at',
#  'Rs.',
#  '1299/-Are',
#  'you',
#  'a',
#  'business',
#  'customer?Get',
#  'up',
#  'to',
#  '30%',
#  'discount',
#  'on',
#  'your',
#  'bulk',
#  'purchase',
#  'and',
#  'many',
#  'more',
#  'exclusive',
#  'offers.Service',
#  '&',
#  'SupportCustomer',
#  'SupportFind',
#  'a',
#  'service',
#  'centerWhatsApp',
#  'Support',
#  '+918067916666Chat',
#  'SupportCheck',
#  'Repair',
#  'StatusFeedback',
#  '&',
#  'Contact',
#  'UsTechnical',
#  'SupportDriver',
#  'Download',
#  '&',
#  'Software',
#  'updateConsult',
#  'Lenovo',
#  'ForumsWarranty',
#  'RelatedWarranty',
#  'LookupInternational',
#  'WarrantyWarranty',
#  'Policies3',
#  'year',
#  'warranty',
#  'at',
#  'Rs.',
#  '1299/-PhonesPhonesLenovo',
#  'LegionMotoData',
#  'CenterData',
#  'CenterSolutionsExplore',
#  'SolutionsAnalytics',
#  '&',
#  'AIAs-a-ServiceBig',
#  'Data',
#  '&',
#  'AnalyticsBusiness',
#  'ApplicationsClient',
#  'Virtualization',
#  '&',
#  'Infrastructure\u200f\u200f\u200eCloud',
#  'ComputingDatabaseDevOpsEdge',
#  'ComputingHigh-Performance',
#  'Computing\u200f\u200f\u200eHyperscale',
#  'ComputingNFV',
#  'Solutions',
#  'for',
#  'CSPsOEMView',
#  'All',
#  'SolutionsSmall',
#  'and',
#  'Medium',
#  'Business',
#  'SolutionsServersExplore',
#  'ServersBlade',
#  'ServersHigh-Density',
#  'ServersMission',
#  'Critical',
#  'ServersRack',
#  'Servers\u200f\u200f\u200eServer',
#  'OptionsTower',
#  'ServersEdge',
#  'ServersView',
#  'All',
#  'ServersThe',
#  'Heart',
#  'of',
#  'the',
#  'Data',
#  'CenterStorageExplore',
#  'StorageDirect-Attached',
#  'StorageStorage-Area',
#  'NetworkTape',
#  'StorageView',
#  'All',
#  'StorageFuture-Proof',
#  'Your',
#  'Enterprise',
#  'StorageNetworkingExplore',
#  'NetworkingEthernet',
#  'RackSwitchEthernet',
#  'Switches',
#  'for',
#  'Flex',
#  '(Embedded)Networking',
#  'SoftwareView',
#  'All',
#  'NetworkingFuture-Proof',
#  'Your',
#  'CloudSoftware-Defined',
#  'InfrastructureCloud',
#  'SolutionsPrivate',
#  'CloudHybrid',
#  'CloudBuild',
#  'Your',
#  'Own',
#  'CloudView',
#  'All',
#  'Software',
#  'DefinedHyperconvergedThinkAgile',
#  'HX',
#  'Series',
#  '(with',
#  'Nutanix)ThinkAgile',
#  'VX',
#  'Series',
#  '(with',
#  'VMware)ServicesExplore',
#  'ServicesThinkAgile',
#  'Advantage',
#  'ServicesPlanning',
#  'ServicesFulfillment',
#  'ServicesDeployment',
#  'ServicesSupport',
#  'ServicesOptimization',
#  'ServicesAsset',
#  'Disposal',
#  'ServicesView',
#  'all',
#  'ServicesThinkAgile',
#  'AdvantageMake',
#  'the',
#  'Most',
#  'of',
#  'Your',
#  'ThinkAgile',
#  'SolutionSoftwareExplore',
#  'SoftwareLenovo',
#  'Intelligent',
#  'Computing',
#  'OrchestrationOperating',
#  'SystemsSecurityXClarity',
#  'Systems',
#  'ManagementView',
#  'all',
#  'SoftwareMarket-Leading',
#  'Software',
#  'for',
#  'the',
#  'Dynamic',
#  'BusinessSupportCustomer',
#  'SupportNeed',
#  'Help?Update',
#  'DriversSearch',
#  'Solutionsdownload',
#  'ManualsSupport',
#  'ResourcesOrder',
#  'SupportExisting',
#  'Order',
#  'HelpReplacement',
#  'PartsGet',
#  'Technical',
#  'HelpSupport',
#  'phone',
#  'listSubmit',
#  'a',
#  'Service',
#  'RequestPremier',
#  'SupportFind',
#  'a',
#  'Service',
#  'ProviderSmart',
#  'DevicesSmart',
#  'DevicesSmart',
#  'HomeExplore',
#  'Smart',
#  'HomeLenovo',
#  'Smart',
#  'DisplayLenovo',
#  'Smart',
#  'ClockLenovo',
#  'Smart',
#  'TabSmart',
#  'TabServices',
#  '&',
#  'SolutionsServices',
#  '&',
#  'SolutionsWarranty',
#  'LookupPC',
#  'ServiceAvoid',
#  'DowntimeIncrease',
#  'ProductivityUnrivaled',
#  'ExpertiseSupport',
#  'ServicesPremier',
#  'SupportPremium',
#  'CareLifecycle',
#  'Warranty',
#  '&',
#  'ProtectionReplacement',
#  'Parts',
#  'StoreDeployment',
#  'ServicesPlanning',
#  '&',
#  'OptimizationAsset',
#  'ManagementCustomizationPost',
#  'DeploymentManaged',
#  'ServicesDevice',
#  'as',
#  'a',
#  'Service',
#  '(DaaS)Services',
#  'by',
#  'IndustryHealthcareEducationSmall',
#  'BusinessData',
#  'Center',
#  'ServicesWhy',
#  'Lenovo',
#  'in',
#  'the',
#  'Data',
#  'CenterExplore',
#  'ServicesImplementation',
#  'ServicesSupport',
#  'ServicesTruScale',
#  'Infrastructure',
#  'ServicesLenovo',
#  'ServicesAccelerate',
#  'your',
#  'Digital',
#  'TransformationsTech',
#  'todaySupportTwitter',
#  '@LenovoSupportCustomer',
#  'SupportRegister',
#  'your',
#  'productTechnical',
#  'SupportOrder',
#  'Replacement',
#  'PartsABOUT',
#  'LENOVOABOUT',
#  'LENOVODiversitySustainabilityInvestors',
#  'RelationsStory',
#  'HubCareers1-800-4199-733SearchLenovoProSign',
#  'In',
#  'To',
#  'LenovoProRegister',
#  'for',
#  'LenovoLearn',
#  'moreLocatorContactHELP',
#  'PLACING',
#  'AN',
#  'ORDER1-800-4199-733Option',
#  '#2FOR',
#  'ORDER',
#  'STATUS',
#  'CALL1800-572-64659AM',
#  'to',
#  '6PMFOR',
#  'CUSTOMER',
#  'SERVICEIdea,',
#  'Legion',
#  '&',
#  'Yoga1800-419-7555Think1800-419-4666HOURSAll',
#  'Days',
#  '9AM',
#  'to',
#  '8PM',
#  'ISTAccountSign',
#  'InMy',
#  'AccountOrdersProduct',
#  'registrationLogoutCartLenovoProLearn',
#  'moreRegister',
#  'for',
#  'LenovoSign',
#  'In',
#  'To',
#  'LenovoProLocatorContactFOR',
#  'CUSTOMER',
#  'SERVICEIdea,',
#  'Legion',
#  '&',
#  'Yoga1800-419-7555Think1800-419-4666FOR',
#  'ORDER',
#  'STATUS',
#  'CALL1800-572-64659AM',
#  'to',
#  '6PMHELP',
#  'PLACING',
#  'AN',
#  'ORDER1-800-4199-733Option',
#  '#2HOURSAll',
#  'Days',
#  '9AM',
#  'to',
#  '8PM',
#  'IST*Sales',
#  'onlyAccountSign',
#  'InMy',
#  'AccountOrdersProduct',
#  'registrationLogoutCartLenovoProSign',
#  'In',
#  'To',
#  'LenovoProRegister',
#  'for',
#  'LenovoLearn',
#  'moreLocatorContactHELP',
#  'PLACING',
#  'AN',
#  'ORDER1-800-4199-733Option',
#  '#2HOURSAll',
#  'Days',
#  '9AM',
#  'to',
#  '8PM',
#  'IST*Sales',
#  'onlyFOR',
#  'ORDER',
#  'STATUS',
#  'CALL1800-572-64659AM',
#  'to',
#  '6PMFOR',
#  'CUSTOMER',
#  'SERVICEIdea,',
#  'Legion',
#  '&',
#  'Yoga1800-419-7555Think1800-419-4666AccountOrdersProduct',
#  'registrationCartLenovoProRegister',
#  'for',
#  'LenovoSign',
#  'In',
#  'To',
#  'LenovoProLearn',
#  'moreLocatorContactHELP',
#  'PLACING',
#  'AN',
#  'ORDER1-800-4199-733Option',
#  '#2HOURSAll',
#  'Days',
#  '9AM',
#  'to',
#  '8PM',
#  'IST*Sales',
#  'onlyFOR',
#  'ORDER',
#  'STATUS',
#  'CALL1800-572-64659AM',
#  'to',
#  '6PMFOR',
#  'CUSTOMER',
#  'SERVICEIdea,',
#  'Legion',
#  '&',
#  'Yoga1800-419-7555Think1800-419-4666AccountOrdersProduct',
#  'registrationCartLenovoProSign',
#  'In',
#  'To',
#  'LenovoProRegister',
#  'for',
#  'LenovoLearn',
#  'moreLocatorContactFOR',
#  'CUSTOMER',
#  'SERVICEIdea,',
#  'Legion',
#  '&',
#  'Yoga1800-419-7555Think1800-419-4666FOR',
#  'ORDER',
#  'STATUS',
#  'CALL1800-572-64659AM',
#  'to',
#  '6PMHELP',
#  'PLACING',
#  'AN',
#  'ORDER1-800-4199-733Option',
#  '#2HOURSAll',
#  'Days',
#  '9AM',
#  'to',
#  '8PM',
#  'IST*Sales',
#  'onlyAccountSign',
#  'InMy',
#  'AccountOrdersProduct',
#  'registrationLogoutCartLenovoProSign',
#  'In',
#  'To',
#  'LenovoProRegister',
#  'for',
#  'LenovoLearn',
#  'moreContactHELP',
#  'PLACING',
#  'AN',
#  'ORDER1-800-4199-733Option',
#  '#2EXISTING',
#  'ORDER',
#  'HELP1-800-4199-733Option',
#  '#2FOR',
#  'CUSTOMER',
#  'SERVICEIdea,',
#  'Legion',
#  '&',
#  'Yoga1800-419-7555Think1800-419-4666HoursAll',
#  'Days',
#  '9AM',
#  'to',
#  '8PM',
#  'IST*Sales',
#  'onlyAccountSign',
#  'InMy',
#  'AccountOrdersProduct',
#  'registrationLogoutCartTop',
#  'SuggestionsView',
#  'all>if',
#  '(typeof',
#  'msApp',
#  '==',
#  'null',
#  '||',
#  'typeof',
#  'msApp',
#  '===',
#  '"undefined"){',
#  'var',
#  'msApp',
#  '=',
#  '{};',
#  '}',
#  'msApp.commonWebResourcePath',
#  '=',
#  '"//static.lenovo.com/fea";',
#  'msApp.customerHost',
#  '=',
#  '"https://www.lenovo.com";',
#  'msApp.contextPath',
#  '=',
#  '"/in/en";',
#  'msApp.storeRootPath',
#  '=',
#  '"/in/en";',
#  'msApp.country',
#  '=',
#  '"in";',
#  'msApp.orgLanguage',
#  '=',
#  '"en_in";',
#  'msApp.language',
#  '=',
#  '"en";',
#  'msApp.previewCmsHost',
#  '=',
#  '"http://global-cms.prod.online.lenovo.com";',
#  'msApp.storename',
#  '=',
#  '"";',
#  'msApp.storeCode',
#  '=',
#  '"inweb";',
#  'msApp.storeType',
#  '=',
#  '"public_consumer";',
#  'var',
#  'webRootlocation',
#  '=',
#  'msApp.storeRootPath;',
#  'var',
#  'commonResourcePath',
#  '=',
#  "'/_ui/desktop/common';",
#  'var',
#  'ACC',
#  '=',
#  '{config',
#  ':',
#  '{}};',
#  'ACC.config.contextPath',
#  '=',
#  'msApp.storeRootPath;',
#  'ACC.config.encodedContextPath',
#  '=',
#  'msApp.storeRootPath;',
#  'ACC.config.commonResourcePath',
#  '=',
#  '"/_ui/desktop/common";',
#  'ACC.config.themeResourcePath',
#  '=',
#  '"/_ui/desktop/theme-blue";',
#  'ACC.config.siteResourcePath',
#  '=',
#  '"/_ui/desktop/site-uspublicsite";',
#  'ACC.config.language',
#  '=',
#  'msApp.language;',
#  'ACC.config.originLanguage',
#  '=',
#  'msApp.orgLanguage;',
#  'ACC.config.rootPath',
#  '=',
#  '"/_ui/desktop";',
#  'ACC.config.CSRFToken',
#  '=',
#  '"1510a5af-311d-4f34-b7c9-ad0b042c8eb3";',
#  'ACC.config.siteName',
#  '=',
#  '"uspublicsite";',
#  'ACC.config.isoCode',
#  '=',
#  'msApp.country.toUpperCase();',
#  'ACC.pwdStrengthVeryWeak',
#  '=',
#  "'Very",
#  "weak';",
#  'ACC.pwdStrengthWeak',
#  '=',
#  "'Weak';",
#  'ACC.pwdStrengthMedium',
#  '=',
#  "'Medium';",
#  'ACC.pwdStrengthStrong',
#  '=',
#  "'Strong';",
#  'ACC.pwdStrengthVeryStrong',
#  '=',
#  "'Very",
#  "strong';",
#  'ACC.pwdStrengthUnsafePwd',
#  '=',
#  "'password.strength.unsafepwd';",
#  'ACC.pwdStrengthTooShortPwd',
#  '=',
#  "'Too",
#  "short';",
#  'ACC.pwdStrengthMinCharText',
#  '=',
#  "'Minimum",
#  'length',
#  'is',
#  '8',
#  "characters';",
#  'ACC.accessibilityLoading',
#  '=',
#  "'Loading...",
#  'Please',
#  "wait...';",
#  'ACC.accessibilityStoresLoaded',
#  ...]

# %%
clean_tokens=tokens[:]
clean_tokens
# Out:
# ['Lenovo',
#  'Official',
#  'India',
#  'Site',
#  '|',
#  'Laptops,',
#  'Tablets,',
#  'Desktops,',
#  'Data',
#  'Center',
#  '|',
#  'Lenovo',
#  'Indiavar',
#  'modalLabels',
#  '=',
#  'window.modalLabels',
#  '?',
#  'modalLabels',
#  ':',
#  '{};',
#  'modalLabels.localization',
#  '=',
#  '{"close"',
#  ':',
#  '"Close",',
#  '"loading"',
#  ':',
#  '"Loading..."};Yo.configure(\'https://qoe-1.yottaa.net/api/v1/configure.rapid.js?key=UcFvHNNMgYjHuw\');',
#  'if(!window.lmd)',
#  'var',
#  'lmd={};',
#  'lmd.yottaa',
#  '=',
#  'window.Yo',
#  '?',
#  'Yo.rum.get().optState',
#  ':',
#  "'yo-not-present';var",
#  'utag_data={country_code:',
#  '"IN",',
#  'language_code:"EN",order_currency_code:',
#  '"INR",',
#  'site_id:',
#  '"INWEB",',
#  'customer_email:',
#  'displayUid,',
#  'customer_name:',
#  'custName};LenovoExploreClosePC',
#  '&',
#  'TABLETSPC',
#  '&',
#  'TABLETSSaleFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Great',
#  'DealsBusiness',
#  'DealsStudent',
#  'LaptopsTablets',
#  '&',
#  'Accessories',
#  'dealsGaming',
#  'DealsClearance',
#  'SaleOther',
#  'DealsLaptops',
#  'Under',
#  '50KAMD',
#  'DealsWorkstation',
#  'DealsAll-in-One',
#  'DealsNew',
#  'ArrivalsLENOVOPRO',
#  'FOR',
#  'BUSINESSJoin',
#  'Now',
#  'to',
#  'Unlock',
#  'free',
#  'digital',
#  'courses,',
#  'Gsuite',
#  'licenses',
#  'and',
#  'easy',
#  'financing',
#  'options',
#  'with',
#  'the',
#  'support',
#  'of',
#  'dedicated',
#  'small',
#  'business',
#  'specialists.Amazing',
#  'DealsSave',
#  'big',
#  'on',
#  'our',
#  'top',
#  'brands',
#  'for',
#  'work,',
#  'school,',
#  'gaming',
#  'and',
#  'much',
#  'more',
#  'while',
#  'supplies',
#  'last.LaptopsFree',
#  'shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Explore',
#  'LaptopsUltra-SlimBusiness',
#  'LaptopsStudent',
#  'Laptop',
#  'DealsConvertiblesGaming',
#  'LaptopsView',
#  'All',
#  'LaptopsBy',
#  'BrandThinkPadThinkBookIdeaPadYogaLegionLenovoBest',
#  'Selling',
#  'LaptopsLegion',
#  '5Ideapad',
#  'Flex',
#  '5Yoga',
#  'Slim',
#  '7Thinkpad',
#  'E14ThinkBook',
#  '14Legion',
#  'Y540Unshackle',
#  'performance.',
#  'Unfetter',
#  'sensibilitiesThinkBook',
#  'Plus',
#  'is',
#  'powered',
#  'by',
#  'the',
#  'latest',
#  '10th',
#  'Gen',
#  'Intel®',
#  'Core™',
#  'processors',
#  'with',
#  'up',
#  'to',
#  '6',
#  'cores',
#  'that',
#  'delivers',
#  'breakthrough',
#  'performanceDesktopsFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Explore',
#  'DesktopsGaming',
#  'DesktopsWorkstationsBusiness',
#  'DesktopsTiny',
#  'DesktopsView',
#  'All',
#  'DesktopsBy',
#  'BrandThinkCentreIdeaCentreLegionThinkStationLenovoBest',
#  'Selling',
#  'DesktopsIdeaCentre',
#  'AIO',
#  '3IdeaCentre',
#  'AIO',
#  '5AIO',
#  '340',
#  '55.88cms',
#  '(22)AIO',
#  '340',
#  '60.96cms',
#  '(24)Legion',
#  'T530',
#  'TowerIdeaCentre',
#  '310sWEEKLY',
#  'DESKTOP',
#  'DEALSClick',
#  'here',
#  'for',
#  'the',
#  'best',
#  'deals',
#  'on',
#  'desktops',
#  'for',
#  'work,',
#  'home,',
#  'gaming',
#  '&',
#  'more.WorkstationsFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Explore',
#  'WorkstationsMobile',
#  'WorkstationsDesktop',
#  'WorkstationsView',
#  'all',
#  'WorkstationsWorkstation',
#  'DealsBy',
#  'BrandThinkPadThinkstationWorkstation',
#  'DealsCheckout',
#  'the',
#  'best',
#  'deals',
#  'on',
#  'WorkstationsNEW',
#  'IN!',
#  'ThinkPad',
#  'P14s',
#  '&',
#  'P15sNow',
#  'with',
#  '10th',
#  'Gen',
#  'Processor.TabletsFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Explore',
#  'TabletsWith',
#  'Android2-in-1',
#  'TabletsNewly',
#  'LaunchedSmart',
#  'HomeView',
#  'all',
#  'TabletsBest',
#  'Selling',
#  'TabletsFor',
#  'KidsFor',
#  'PerformanceFor',
#  'a',
#  'GiftBest',
#  'BargainIT',
#  'IS',
#  'TIME',
#  'TO',
#  'UN-LAPTOP,',
#  'AND',
#  'GOThe',
#  'perfect',
#  'balance',
#  'between',
#  'tablet',
#  'portability',
#  'and',
#  'Chromebook',
#  'utilityTablet',
#  'DealsFind',
#  'the',
#  'perfect',
#  'tablet',
#  'or',
#  'smart',
#  'device',
#  'for',
#  'you',
#  'and',
#  'the',
#  'whole',
#  'family.',
#  'Enjoy',
#  'weekly',
#  'discounts',
#  'today!AccessoriesFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733ProductsDocksChargers',
#  '&',
#  'BatteriesMice',
#  '&',
#  'KeyboardCables',
#  '&',
#  'AdaptersCases',
#  '&',
#  'BagsView',
#  'All',
#  'AccessoriesFeaturedGaming',
#  'AccessoriesStudent',
#  'AccessoriesAccessories',
#  'FinderFind',
#  'the',
#  'right',
#  'accessory',
#  'for',
#  'your',
#  'machineMonitorsFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Explore',
#  'MonitorsMonitors',
#  'for',
#  'WorkMonitors',
#  'for',
#  'HomeMonitors',
#  'for',
#  'GamingView',
#  'All',
#  'MonitorsMonitor',
#  'SaleShop',
#  'Weekly',
#  'deals',
#  '&',
#  'complete',
#  'your',
#  'work',
#  'from',
#  'home,',
#  'gaming',
#  'or',
#  'school',
#  'set',
#  'up',
#  'today!THINKVISION',
#  'M14tExperience',
#  'work',
#  'on-the-go',
#  'like',
#  'no',
#  'otherGamingFree',
#  'Shipping6',
#  'Months',
#  'No-cost',
#  'EMIBuild',
#  'your',
#  'own',
#  'laptopTo',
#  'buy,',
#  'call',
#  'us',
#  'on',
#  '1800',
#  '4199',
#  '733Explore',
#  'GamingLaptopsDesktopsMonitorsAccessoriesCustomized',
#  'Gaming',
#  'LaptopsBest',
#  'Selling',
#  'ProductsLegion',
#  '5iIdeaPad',
#  'Gaming',
#  '3iIdeaPad',
#  'L340Legion',
#  'Y540Legion',
#  '7iLegion',
#  'Y7000Types',
#  'of',
#  'GamingAvid',
#  'GamingLight',
#  'GamingCustomized',
#  'Gaming',
#  'LaptopsYour',
#  'Gaming',
#  'PC.',
#  'Your',
#  'Configurations.',
#  'Your',
#  'DealsBusiness',
#  'SolutionsBusiness',
#  'SolutionsDevice',
#  'as',
#  'a',
#  'Service',
#  '(DAAS)Premier',
#  'SupportFactory',
#  'ServicesReplacement',
#  'Parts3',
#  'year',
#  'warranty',
#  'at',
#  'Rs.',
#  '1299/-Are',
#  'you',
#  'a',
#  'business',
#  'customer?Get',
#  'up',
#  'to',
#  '30%',
#  'discount',
#  'on',
#  'your',
#  'bulk',
#  'purchase',
#  'and',
#  'many',
#  'more',
#  'exclusive',
#  'offers.Service',
#  '&',
#  'SupportCustomer',
#  'SupportFind',
#  'a',
#  'service',
#  'centerWhatsApp',
#  'Support',
#  '+918067916666Chat',
#  'SupportCheck',
#  'Repair',
#  'StatusFeedback',
#  '&',
#  'Contact',
#  'UsTechnical',
#  'SupportDriver',
#  'Download',
#  '&',
#  'Software',
#  'updateConsult',
#  'Lenovo',
#  'ForumsWarranty',
#  'RelatedWarranty',
#  'LookupInternational',
#  'WarrantyWarranty',
#  'Policies3',
#  'year',
#  'warranty',
#  'at',
#  'Rs.',
#  '1299/-PhonesPhonesLenovo',
#  'LegionMotoData',
#  'CenterData',
#  'CenterSolutionsExplore',
#  'SolutionsAnalytics',
#  '&',
#  'AIAs-a-ServiceBig',
#  'Data',
#  '&',
#  'AnalyticsBusiness',
#  'ApplicationsClient',
#  'Virtualization',
#  '&',
#  'Infrastructure\u200f\u200f\u200eCloud',
#  'ComputingDatabaseDevOpsEdge',
#  'ComputingHigh-Performance',
#  'Computing\u200f\u200f\u200eHyperscale',
#  'ComputingNFV',
#  'Solutions',
#  'for',
#  'CSPsOEMView',
#  'All',
#  'SolutionsSmall',
#  'and',
#  'Medium',
#  'Business',
#  'SolutionsServersExplore',
#  'ServersBlade',
#  'ServersHigh-Density',
#  'ServersMission',
#  'Critical',
#  'ServersRack',
#  'Servers\u200f\u200f\u200eServer',
#  'OptionsTower',
#  'ServersEdge',
#  'ServersView',
#  'All',
#  'ServersThe',
#  'Heart',
#  'of',
#  'the',
#  'Data',
#  'CenterStorageExplore',
#  'StorageDirect-Attached',
#  'StorageStorage-Area',
#  'NetworkTape',
#  'StorageView',
#  'All',
#  'StorageFuture-Proof',
#  'Your',
#  'Enterprise',
#  'StorageNetworkingExplore',
#  'NetworkingEthernet',
#  'RackSwitchEthernet',
#  'Switches',
#  'for',
#  'Flex',
#  '(Embedded)Networking',
#  'SoftwareView',
#  'All',
#  'NetworkingFuture-Proof',
#  'Your',
#  'CloudSoftware-Defined',
#  'InfrastructureCloud',
#  'SolutionsPrivate',
#  'CloudHybrid',
#  'CloudBuild',
#  'Your',
#  'Own',
#  'CloudView',
#  'All',
#  'Software',
#  'DefinedHyperconvergedThinkAgile',
#  'HX',
#  'Series',
#  '(with',
#  'Nutanix)ThinkAgile',
#  'VX',
#  'Series',
#  '(with',
#  'VMware)ServicesExplore',
#  'ServicesThinkAgile',
#  'Advantage',
#  'ServicesPlanning',
#  'ServicesFulfillment',
#  'ServicesDeployment',
#  'ServicesSupport',
#  'ServicesOptimization',
#  'ServicesAsset',
#  'Disposal',
#  'ServicesView',
#  'all',
#  'ServicesThinkAgile',
#  'AdvantageMake',
#  'the',
#  'Most',
#  'of',
#  'Your',
#  'ThinkAgile',
#  'SolutionSoftwareExplore',
#  'SoftwareLenovo',
#  'Intelligent',
#  'Computing',
#  'OrchestrationOperating',
#  'SystemsSecurityXClarity',
#  'Systems',
#  'ManagementView',
#  'all',
#  'SoftwareMarket-Leading',
#  'Software',
#  'for',
#  'the',
#  'Dynamic',
#  'BusinessSupportCustomer',
#  'SupportNeed',
#  'Help?Update',
#  'DriversSearch',
#  'Solutionsdownload',
#  'ManualsSupport',
#  'ResourcesOrder',
#  'SupportExisting',
#  'Order',
#  'HelpReplacement',
#  'PartsGet',
#  'Technical',
#  'HelpSupport',
#  'phone',
#  'listSubmit',
#  'a',
#  'Service',
#  'RequestPremier',
#  'SupportFind',
#  'a',
#  'Service',
#  'ProviderSmart',
#  'DevicesSmart',
#  'DevicesSmart',
#  'HomeExplore',
#  'Smart',
#  'HomeLenovo',
#  'Smart',
#  'DisplayLenovo',
#  'Smart',
#  'ClockLenovo',
#  'Smart',
#  'TabSmart',
#  'TabServices',
#  '&',
#  'SolutionsServices',
#  '&',
#  'SolutionsWarranty',
#  'LookupPC',
#  'ServiceAvoid',
#  'DowntimeIncrease',
#  'ProductivityUnrivaled',
#  'ExpertiseSupport',
#  'ServicesPremier',
#  'SupportPremium',
#  'CareLifecycle',
#  'Warranty',
#  '&',
#  'ProtectionReplacement',
#  'Parts',
#  'StoreDeployment',
#  'ServicesPlanning',
#  '&',
#  'OptimizationAsset',
#  'ManagementCustomizationPost',
#  'DeploymentManaged',
#  'ServicesDevice',
#  'as',
#  'a',
#  'Service',
#  '(DaaS)Services',
#  'by',
#  'IndustryHealthcareEducationSmall',
#  'BusinessData',
#  'Center',
#  'ServicesWhy',
#  'Lenovo',
#  'in',
#  'the',
#  'Data',
#  'CenterExplore',
#  'ServicesImplementation',
#  'ServicesSupport',
#  'ServicesTruScale',
#  'Infrastructure',
#  'ServicesLenovo',
#  'ServicesAccelerate',
#  'your',
#  'Digital',
#  'TransformationsTech',
#  'todaySupportTwitter',
#  '@LenovoSupportCustomer',
#  'SupportRegister',
#  'your',
#  'productTechnical',
#  'SupportOrder',
#  'Replacement',
#  'PartsABOUT',
#  'LENOVOABOUT',
#  'LENOVODiversitySustainabilityInvestors',
#  'RelationsStory',
#  'HubCareers1-800-4199-733SearchLenovoProSign',
#  'In',
#  'To',
#  'LenovoProRegister',
#  'for',
#  'LenovoLearn',
#  'moreLocatorContactHELP',
#  'PLACING',
#  'AN',
#  'ORDER1-800-4199-733Option',
#  '#2FOR',
#  'ORDER',
#  'STATUS',
#  'CALL1800-572-64659AM',
#  'to',
#  '6PMFOR',
#  'CUSTOMER',
#  'SERVICEIdea,',
#  'Legion',
#  '&',
#  'Yoga1800-419-7555Think1800-419-4666HOURSAll',
#  'Days',
#  '9AM',
#  'to',
#  '8PM',
#  'ISTAccountSign',
#  'InMy',
#  'AccountOrdersProduct',
#  'registrationLogoutCartLenovoProLearn',
#  'moreRegister',
#  'for',
#  'LenovoSign',
#  'In',
#  'To',
#  'LenovoProLocatorContactFOR',
#  'CUSTOMER',
#  'SERVICEIdea,',
#  'Legion',
#  '&',
#  'Yoga1800-419-7555Think1800-419-4666FOR',
#  'ORDER',
#  'STATUS',
#  'CALL1800-572-64659AM',
#  'to',
#  '6PMHELP',
#  'PLACING',
#  'AN',
#  'ORDER1-800-4199-733Option',
#  '#2HOURSAll',
#  'Days',
#  '9AM',
#  'to',
#  '8PM',
#  'IST*Sales',
#  'onlyAccountSign',
#  'InMy',
#  'AccountOrdersProduct',
#  'registrationLogoutCartLenovoProSign',
#  'In',
#  'To',
#  'LenovoProRegister',
#  'for',
#  'LenovoLearn',
#  'moreLocatorContactHELP',
#  'PLACING',
#  'AN',
#  'ORDER1-800-4199-733Option',
#  '#2HOURSAll',
#  'Days',
#  '9AM',
#  'to',
#  '8PM',
#  'IST*Sales',
#  'onlyFOR',
#  'ORDER',
#  'STATUS',
#  'CALL1800-572-64659AM',
#  'to',
#  '6PMFOR',
#  'CUSTOMER',
#  'SERVICEIdea,',
#  'Legion',
#  '&',
#  'Yoga1800-419-7555Think1800-419-4666AccountOrdersProduct',
#  'registrationCartLenovoProRegister',
#  'for',
#  'LenovoSign',
#  'In',
#  'To',
#  'LenovoProLearn',
#  'moreLocatorContactHELP',
#  'PLACING',
#  'AN',
#  'ORDER1-800-4199-733Option',
#  '#2HOURSAll',
#  'Days',
#  '9AM',
#  'to',
#  '8PM',
#  'IST*Sales',
#  'onlyFOR',
#  'ORDER',
#  'STATUS',
#  'CALL1800-572-64659AM',
#  'to',
#  '6PMFOR',
#  'CUSTOMER',
#  'SERVICEIdea,',
#  'Legion',
#  '&',
#  'Yoga1800-419-7555Think1800-419-4666AccountOrdersProduct',
#  'registrationCartLenovoProSign',
#  'In',
#  'To',
#  'LenovoProRegister',
#  'for',
#  'LenovoLearn',
#  'moreLocatorContactFOR',
#  'CUSTOMER',
#  'SERVICEIdea,',
#  'Legion',
#  '&',
#  'Yoga1800-419-7555Think1800-419-4666FOR',
#  'ORDER',
#  'STATUS',
#  'CALL1800-572-64659AM',
#  'to',
#  '6PMHELP',
#  'PLACING',
#  'AN',
#  'ORDER1-800-4199-733Option',
#  '#2HOURSAll',
#  'Days',
#  '9AM',
#  'to',
#  '8PM',
#  'IST*Sales',
#  'onlyAccountSign',
#  'InMy',
#  'AccountOrdersProduct',
#  'registrationLogoutCartLenovoProSign',
#  'In',
#  'To',
#  'LenovoProRegister',
#  'for',
#  'LenovoLearn',
#  'moreContactHELP',
#  'PLACING',
#  'AN',
#  'ORDER1-800-4199-733Option',
#  '#2EXISTING',
#  'ORDER',
#  'HELP1-800-4199-733Option',
#  '#2FOR',
#  'CUSTOMER',
#  'SERVICEIdea,',
#  'Legion',
#  '&',
#  'Yoga1800-419-7555Think1800-419-4666HoursAll',
#  'Days',
#  '9AM',
#  'to',
#  '8PM',
#  'IST*Sales',
#  'onlyAccountSign',
#  'InMy',
#  'AccountOrdersProduct',
#  'registrationLogoutCartTop',
#  'SuggestionsView',
#  'all>if',
#  '(typeof',
#  'msApp',
#  '==',
#  'null',
#  '||',
#  'typeof',
#  'msApp',
#  '===',
#  '"undefined"){',
#  'var',
#  'msApp',
#  '=',
#  '{};',
#  '}',
#  'msApp.commonWebResourcePath',
#  '=',
#  '"//static.lenovo.com/fea";',
#  'msApp.customerHost',
#  '=',
#  '"https://www.lenovo.com";',
#  'msApp.contextPath',
#  '=',
#  '"/in/en";',
#  'msApp.storeRootPath',
#  '=',
#  '"/in/en";',
#  'msApp.country',
#  '=',
#  '"in";',
#  'msApp.orgLanguage',
#  '=',
#  '"en_in";',
#  'msApp.language',
#  '=',
#  '"en";',
#  'msApp.previewCmsHost',
#  '=',
#  '"http://global-cms.prod.online.lenovo.com";',
#  'msApp.storename',
#  '=',
#  '"";',
#  'msApp.storeCode',
#  '=',
#  '"inweb";',
#  'msApp.storeType',
#  '=',
#  '"public_consumer";',
#  'var',
#  'webRootlocation',
#  '=',
#  'msApp.storeRootPath;',
#  'var',
#  'commonResourcePath',
#  '=',
#  "'/_ui/desktop/common';",
#  'var',
#  'ACC',
#  '=',
#  '{config',
#  ':',
#  '{}};',
#  'ACC.config.contextPath',
#  '=',
#  'msApp.storeRootPath;',
#  'ACC.config.encodedContextPath',
#  '=',
#  'msApp.storeRootPath;',
#  'ACC.config.commonResourcePath',
#  '=',
#  '"/_ui/desktop/common";',
#  'ACC.config.themeResourcePath',
#  '=',
#  '"/_ui/desktop/theme-blue";',
#  'ACC.config.siteResourcePath',
#  '=',
#  '"/_ui/desktop/site-uspublicsite";',
#  'ACC.config.language',
#  '=',
#  'msApp.language;',
#  'ACC.config.originLanguage',
#  '=',
#  'msApp.orgLanguage;',
#  'ACC.config.rootPath',
#  '=',
#  '"/_ui/desktop";',
#  'ACC.config.CSRFToken',
#  '=',
#  '"1510a5af-311d-4f34-b7c9-ad0b042c8eb3";',
#  'ACC.config.siteName',
#  '=',
#  '"uspublicsite";',
#  'ACC.config.isoCode',
#  '=',
#  'msApp.country.toUpperCase();',
#  'ACC.pwdStrengthVeryWeak',
#  '=',
#  "'Very",
#  "weak';",
#  'ACC.pwdStrengthWeak',
#  '=',
#  "'Weak';",
#  'ACC.pwdStrengthMedium',
#  '=',
#  "'Medium';",
#  'ACC.pwdStrengthStrong',
#  '=',
#  "'Strong';",
#  'ACC.pwdStrengthVeryStrong',
#  '=',
#  "'Very",
#  "strong';",
#  'ACC.pwdStrengthUnsafePwd',
#  '=',
#  "'password.strength.unsafepwd';",
#  'ACC.pwdStrengthTooShortPwd',
#  '=',
#  "'Too",
#  "short';",
#  'ACC.pwdStrengthMinCharText',
#  '=',
#  "'Minimum",
#  'length',
#  'is',
#  '8',
#  "characters';",
#  'ACC.accessibilityLoading',
#  '=',
#  "'Loading...",
#  'Please',
#  "wait...';",
#  'ACC.accessibilityStoresLoaded',
#  ...]

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
ps = PorterStemmer()

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['Lenovo Official India Site | Laptops, Tablets, Desktops, Data Center | Lenovo Indiavar modalLabels = window.modalLabels ?', 'modalLabels : {};\n      modalLabels.localization = {"close" : "Close", "loading" : "Loading..."};Yo.configure(\'https://qoe-1.yottaa.net/api/v1/configure.rapid.js?key=UcFvHNNMgYjHuw\');\n    if(!window.lmd)  var lmd={};\n    lmd.yottaa = window.Yo ?', 'Yo.rum.get().optState : \'yo-not-present\';var utag_data={country_code: "IN",\n        \tlanguage_code:"EN",order_currency_code: "INR",\n       \t\tsite_id: "INWEB",\n            customer_email: displayUid, customer_name: custName};LenovoExploreClosePC & TABLETSPC & TABLETSSaleFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Great DealsBusiness DealsStudent LaptopsTablets & Accessories dealsGaming DealsClearance SaleOther DealsLaptops Under 50KAMD DealsWorkstation DealsAll-in-One DealsNew ArrivalsLENOVOPRO FOR BUSINESSJoin Now to Unlock free digital courses, Gsuite licenses and easy financing options with the support of dedicated small business specialists.Amazing DealsSave big on our top brands for work, school, gaming and much more while supplies last.LaptopsFree shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore LaptopsUltra-SlimBusiness LaptopsStudent Laptop DealsConvertiblesGaming LaptopsView All LaptopsBy BrandThinkPadThinkBookIdeaPadYogaLegionLenovoBest Selling LaptopsLegion 5Ideapad Flex 5Yoga Slim 7Thinkpad E14ThinkBook 14Legion Y540Unshackle performance.', 'Unfetter sensibilitiesThinkBook Plus is powered by the latest 10th Gen Intel® Core™ processors with up to 6 cores that delivers breakthrough performanceDesktopsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore DesktopsGaming DesktopsWorkstationsBusiness DesktopsTiny DesktopsView All DesktopsBy BrandThinkCentreIdeaCentreLegionThinkStationLenovoBest Selling DesktopsIdeaCentre AIO 3IdeaCentre AIO 5AIO 340 55.88cms (22)AIO 340 60.96cms (24)Legion T530 TowerIdeaCentre 310sWEEKLY DESKTOP DEALSClick here for the best deals on desktops for work, home, gaming & more.WorkstationsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore WorkstationsMobile WorkstationsDesktop WorkstationsView all WorkstationsWorkstation DealsBy BrandThinkPadThinkstationWorkstation DealsCheckout the best deals on WorkstationsNEW IN!', 'ThinkPad P14s & P15sNow with 10th Gen Processor.TabletsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore TabletsWith Android2-in-1 TabletsNewly LaunchedSmart HomeView all TabletsBest Selling TabletsFor KidsFor PerformanceFor a GiftBest BargainIT IS TIME TO UN-LAPTOP, AND GOThe perfect balance between tablet portability and Chromebook utilityTablet DealsFind the perfect tablet or smart device for you and the whole family.', 'Enjoy weekly discounts today!AccessoriesFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733ProductsDocksChargers & BatteriesMice & KeyboardCables & AdaptersCases & BagsView All AccessoriesFeaturedGaming AccessoriesStudent AccessoriesAccessories FinderFind the right accessory for your machineMonitorsFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore MonitorsMonitors for WorkMonitors for HomeMonitors for GamingView All MonitorsMonitor SaleShop Weekly deals & complete your work from home, gaming or school set up today!THINKVISION M14tExperience work on-the-go like no otherGamingFree Shipping6 Months No-cost EMIBuild your own laptopTo buy, call us on 1800 4199 733Explore GamingLaptopsDesktopsMonitorsAccessoriesCustomized Gaming LaptopsBest Selling ProductsLegion 5iIdeaPad Gaming 3iIdeaPad L340Legion Y540Legion 7iLegion Y7000Types of GamingAvid GamingLight GamingCustomized Gaming LaptopsYour Gaming PC.', 'Your Configurations.', 'Your DealsBusiness SolutionsBusiness SolutionsDevice as ...
# Stemmed Sentence: ['lenovo official india site | laptops, tablets, desktops, data center | lenovo indiavar modallabels = window.modallabels ?', 'modallabels : {};\n      modallabels.localization = {"close" : "close", "loading" : "loading..."};yo.configure(\'https://qoe-1.yottaa.net/api/v1/configure.rapid.js?key=ucfvhnnmgyjhuw\');\n    if(!window.lmd)  var lmd={};\n    lmd.yottaa = window.yo ?', 'yo.rum.get().optstate : \'yo-not-present\';var utag_data={country_code: "in",\n        \tlanguage_code:"en",order_currency_code: "inr",\n       \t\tsite_id: "inweb",\n            customer_email: displayuid, customer_name: custname};lenovoexploreclosepc & tabletspc & tabletssalefree shipping6 months no-cost emibuild your own laptopto buy, call us on 1800 4199 733great dealsbusiness dealsstudent laptopstablets & accessories dealsgaming dealsclearance saleother dealslaptops under 50kamd dealsworkstation dealsall-in-one dealsnew arrivalslenovopro for businessjoin now to unlock free digital courses, gsuite licenses and easy financing options with the support of dedicated small business specialists.amazing dealssave big on our top brands for work, school, gaming and much more while supplies last.laptopsfree shipping6 months no-cost emibuild your own laptopto buy, call us on 1800 4199 733explore laptopsultra-slimbusiness laptopsstudent laptop dealsconvertiblesgaming laptopsview all laptopsby brandthinkpadthinkbookideapadyogalegionlenovobest selling laptopslegion 5ideapad flex 5yoga slim 7thinkpad e14thinkbook 14legion y540unshackle performance.', 'unfetter sensibilitiesthinkbook plus is powered by the latest 10th gen intel® core™ processors with up to 6 cores that delivers breakthrough performancedesktopsfree shipping6 months no-cost emibuild your own laptopto buy, call us on 1800 4199 733explore desktopsgaming desktopsworkstationsbusiness desktopstiny desktopsview all desktopsby brandthinkcentreideacentrelegionthinkstationlenovobest selling desktopsideacentre aio 3ideacentre aio 5aio 340 55.88cms (22)aio 340 60.96cms (24)legion t530 towerideacentre 310sweekly desktop dealsclick here for the best deals on desktops for work, home, gaming & more.workstationsfree shipping6 months no-cost emibuild your own laptopto buy, call us on 1800 4199 733explore workstationsmobile workstationsdesktop workstationsview all workstationsworkstation dealsby brandthinkpadthinkstationworkstation dealscheckout the best deals on workstationsnew in!', 'thinkpad p14s & p15snow with 10th gen processor.tabletsfree shipping6 months no-cost emibuild your own laptopto buy, call us on 1800 4199 733explore tabletswith android2-in-1 tabletsnewly launchedsmart homeview all tabletsbest selling tabletsfor kidsfor performancefor a giftbest bargainit is time to un-laptop, and gothe perfect balance between tablet portability and chromebook utilitytablet dealsfind the perfect tablet or smart device for you and the whole family.', 'enjoy weekly discounts today!accessoriesfree shipping6 months no-cost emibuild your own laptopto buy, call us on 1800 4199 733productsdockschargers & batteriesmice & keyboardcables & adapterscases & bagsview all accessoriesfeaturedgaming accessoriesstudent accessoriesaccessories finderfind the right accessory for your machinemonitorsfree shipping6 months no-cost emibuild your own laptopto buy, call us on 1800 4199 733explore monitorsmonitors for workmonitors for homemonitors for gamingview all monitorsmonitor saleshop weekly deals & complete your work from home, gaming or school set up today!thinkvision m14texperience work on-the-go like no othergamingfree shipping6 months no-cost emibuild your own laptopto buy, call us on 1800 4199 733explore gaminglaptopsdesktopsmonitorsaccessoriescustomized gaming laptopsbest selling productslegion 5iideapad gaming 3iideapad l340legion y540legion 7ilegion y7000types of gamingavid gaminglight gamingcustomized gaming laptopsyour gaming pc.', 'your configurations.', 'your dealsbusiness solutionsbusiness solutionsdevice as  ...

# %%
for t in tokens:
    if t in stopwords.words('english'):
        clean_tokens.remove(t)

# %%
freq=nltk.FreqDist(clean_tokens)
freq
freq.plot(20,cumulative=False)
